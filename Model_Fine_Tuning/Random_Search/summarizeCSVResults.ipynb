# %%
import pandas as pd

df = pd.read_csv("random_search_results.csv")
#df_sorted = df.sort_values(by='weighted_score', ascending=False)
df_sorted = df.sort_values(by='accuracy', ascending=False)
df_sorted.reset_index(drop=True, inplace=True)
df_sorted
# Out:
#      trial  filters  conv_layers  dense_units  dropout  batch_norm optimizer  \
# 0      137       64            3          128     0.46        True   rmsprop
# 1      126       32            3          128     0.33        True      adam
# 2       79       64            3          256     0.56        True   rmsprop
# 3      128       32            3          512     0.59        True      adam
# 4      104       32            4          512     0.46        True      adam
# ..     ...      ...          ...          ...      ...         ...       ...
# 133     50       32            3          512     0.52        True      adam
# 134     33       32            2          256     0.52        True      adam
# 135     24       32            3          256     0.53        True      adam
# 136     76       64            2          512     0.54       False   rmsprop
# 137     69       32            4          128     0.41       False      adam
#
#          lr  accuracy  precision    recall  f1_score  weighted_score  \
# 0    0.0005  0.952840   0.952929  0.952840  0.952639        0.824192
# 1    0.0010  0.945926   0.946351  0.945926  0.945805        0.800881
# 2    0.0005  0.943951   0.945732  0.943951  0.943971        0.795472
# 3    0.0005  0.942469   0.943618  0.942469  0.942355        0.789851
# 4    0.0005  0.939753   0.940450  0.939753  0.939535        0.780326
# ..      ...       ...        ...       ...       ...             ...
# 133  0.0050  0.217284   0.066192  0.217284  0.099410        0.000311
# 134  0.0050  0.185679   0.055198  0.185679  0.080039        0.000152
# 135  0.0050  0.111111   0.012346  0.111111  0.022222        0.000003
# 136  0.0050  0.111111   0.012346  0.111111  0.022222        0.000003
# 137  0.0050  0.111111   0.012346  0.111111  0.022222        0.000003
#
#     flattening_layers
# 0               GAP2D
# 1               GAP2D
# 2               GAP2D
# 3               GAP2D
# 4               GAP2D
# ..                ...
# 133           flatten
# 134           flatten
# 135           flatten
# 136           flatten
# 137           flatten
#
# [138 rows x 14 columns]
